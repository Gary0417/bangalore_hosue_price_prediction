# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Loading

# %%
df= pd.read_csv("data/Bengaluru_House_Data_cData Loadingleaned.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7692 entries, 0 to 7691
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area_type      7692 non-null   object
#  1   location       7692 non-null   object
#  2   total_sqft     7692 non-null   float64
#  3   bath           7692 non-null   float64
#  4   balcony        7692 non-null   float64
#  5   price          7692 non-null   float64
#  6   bedroom        7692 non-null   float64
#  7   ready_to_move  7692 non-null   int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 480.9+ KB

# %%
df['ready_to_move'] = df['ready_to_move'].astype('object')

# %% [markdown]
# ## Numerical Features

# %%
df.describe()
# Out:
#          total_sqft         bath      balcony        price      bedroom
# count   7692.000000  7692.000000  7692.000000  7692.000000  7692.000000
# mean    1414.245113     2.524181     1.550832    99.710992     2.604004
# std      618.567995     1.129762     0.791248    83.473433     1.096904
# min      250.000000     1.000000     0.000000     8.000000     1.000000
# 25%     1080.000000     2.000000     1.000000    50.605000     2.000000
# 50%     1250.000000     2.000000     2.000000    75.000000     2.000000
# 75%     1645.000000     3.000000     2.000000   120.000000     3.000000
# max    10000.000000    27.000000     3.000000  1250.000000    27.000000

# %%
df_numerical = df.select_dtypes(exclude = ['object'])
for feature in df_numerical:
    sns.distplot(df[feature])
    plt.show()
# Out:
# C:\Users\garyt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\garyt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\garyt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\garyt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\garyt\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Correlation between numerical features

# %%
corr = df.corr()
plt.figure(figsize = (10,8))
sns.heatmap(corr, annot= True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the heatmap we can observe that:
# - there is a strong positive correlation between 'total_sqft' and 'price',
# - 'bath' and 'bedroom' exhibit high positive correlations with 'price', suggesting that properties with more bathrooms and bedrooms tend to be priced higher
# - 'bath' and 'bedroom' are strongly positive correlated with each other

# %%
df_numerical_features = df_numerical.drop(['price'], axis = 1 )
for col in df_numerical_features.columns:
    sns.lmplot(x = col, y = 'price', data = df)

# %% [markdown]
# From the above plots we can see that:
#
# - as the total square feet of a house increases, the price also tends to increase.
# - higher bathroom counts generally associated with higher prices.
# - higher bedroom counts generally associated with higher prices.
# - having more balconies is associated with a higher sale price, although the effect is somewhat smaller in magnitude compared to other variables

# %% [markdown]
# ## Categorical Features

# %%
df_cat_features = df[['area_type', 'location','ready_to_move']]

# %%
df_cat_features_wo_location = df_cat_features.drop(['location'], axis = 1)
for col in df_cat_features_wo_location.columns:
    cat_num = df_cat_features_wo_location[col].value_counts()
    chart = sns.barplot(x = cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 20)
    plt.show()

# %%
location_num = df_cat_features['location'].value_counts()[:20]
chart = sns.barplot(x = location_num, y = location_num.index)
plt.show()

# %% [markdown]
# ### Top 20 locations with the highest price

# %%
pd.pivot_table(df, index = ['location'], values = 'price').sort_values('price', ascending = False)[:20]
# Out:
#                             price
# location
# Cunningham Road        744.555556
# Kodihalli              436.916667
# Benson Town            346.743333
# HAL 2nd Stage          339.272727
# Giri Nagar             309.727273
# Mahalakshmi Layout     294.846154
# Rajaji Nagar           279.055467
# Indira Nagar           277.750000
# Iblur Village          236.000000
# Cooke Town             227.333333
# Sarakki Nagar          225.823000
# 2nd Stage Nagarbhavi   218.333333
# Frazer Town            215.480000
# 1st Block Jayanagar    207.500000
# Hebbal Kempapura       198.960000
# Hosakerehalli          198.545185
# Banashankari Stage II  198.168000
# Malleshwaram           193.084615
# Konanakunte            191.666667
# Basaveshwara Nagar     183.619048

# %% [markdown]
# ### Top 20 locations with the lowest price

# %%
pd.pivot_table(df, index = 'location', values = 'price').sort_values('price', ascending = True)[:20]
# Out:
#                                  price
# location
# Attibele                     25.788889
# Ananth Nagar                 28.245217
# Chandapura                   31.483152
# Kereguddadahalli             33.258333
# Anekal                       33.922727
# Bommasandra Industrial Area  36.902222
# Kammasandra                  38.079474
# Sarjapura - Attibele Road    38.631667
# Channasandra                 39.807308
# Dommasandra                  40.134000
# Hoskote                      40.460357
# Bisuvanahalli                40.925556
# Bommasandra                  41.234074
# Kengeri Satellite Town       41.543167
# Sompura                      43.090909
# Doddathoguru                 43.995417
# Electronic City Phase II     44.301368
# Kambipura                    44.375833
# Yelahanka New Town           44.448276
# Abbigere                     44.522308

# %% [markdown]
# ### 'ready_to_move'

# %%
ready_to_move_price = df.groupby('ready_to_move')['price'].mean()
ready_to_move_price
# Out:
# ready_to_move
# 0     88.182509
# 1    102.757968
# Name: price, dtype: float64

# %%
sns.boxplot(x='ready_to_move', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='ready_to_move', ylabel='price'>

# %% [markdown]
# Houses that are move-in ready are on average **more expensive** than houses that are still under construction.

# %% [markdown]
# ### 'area_type'

# %%
ready_to_move_price = df.groupby('area_type')['price'].mean().sort_values(ascending = False)
ready_to_move_price
# Out:
# area_type
# Plot  Area              158.428837
# Built-up  Area           93.749551
# Carpet  Area             92.739298
# Super built-up  Area     91.424084
# Name: price, dtype: float64

# %%
sns.boxplot(x='area_type', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='area_type', ylabel='price'>

# %%
pt = pd.pivot_table(df, index = 'location', columns = 'ready_to_move', values = 'price')
pt.dropna(inplace = True)

# %% [markdown]
# ### Location where move-in ready house are more expensive.

# %%
pt1 = pt[pt[1] > pt[0]].sort_values(1, ascending = False)
pt1
# Out:
# ready_to_move                         0           1
# location
# Cunningham Road              712.500000  753.714286
# HAL 2nd Stage                140.000000  383.555556
# Giri Nagar                   175.000000  323.200000
# Rajaji Nagar                 113.741818  307.468750
# Iblur Village                139.600000  273.076923
# Sarakki Nagar                168.115000  240.250000
# Hosakerehalli                 85.492500  218.206522
# Malleshwaram                  75.000000  196.192105
# Judicial Layout               52.333333  195.161000
# Basaveshwara Nagar            70.000000  189.300000
# Doddaballapur                 49.000000  189.250000
# Ulsoor                        60.000000  146.923077
# HRBR Layout                  120.000000  145.300000
# Banashankari Stage VI         72.122500  141.500000
# Old Madras Road               74.454706  130.015625
# Seegehalli                    36.160000  128.214286
# Sarjapur  Road                82.992672  128.130377
# Bhoganhalli                   85.366250  125.876923
# Banashankari Stage III        86.930000  116.000000
# Whitefield                    99.428614  115.796949
# Kodigehalli                   83.665000  113.000000
# Ramagondanahalli              53.801667  112.692308
# Jalahalli                     48.545000  110.251154
# Nagavara                      55.000000  110.016154
# Murugeshpalya                 48.000000  103.166667
# Thanisandra                   85.127553  100.710357
# Vijayanagar                   88.122667   98.285714
# Hennur Road                   89.005957   98.189143
# Kaikondrahalli                25.575000   94.954545
# Kanakpura Road                74.779098   94.847667
# Vidyaranyapura                64.000000   94.050000
# Yelachenahalli                38.000000   91.083333
# JP Nagar                      72.035769   90.072424
# NRI Layout                    45.560000   87.206667
# Ambalipura                    30.336667   87.176250
# Marathahalli                  69.916667   86.899247
# Yelahanka                     84.669444   86.047183
# Banjara Layout                76.500000   85.811111
# Ramamurthy Nagar              54.446667   83.515128
# Kadubeesanahalli              35.000000   83.500000
# Rachenahalli                  32.040000   77.198889
# Kothanur                      69.750000   77.092105
# Munnekollal                   54.986000   76.818182
# Tumkur Road                   67.931000   76.221111
# Bannerghatta Road             71.728182   75.514568
# Akshaya Nagar                 72.500000   73.962791
# Magadi Road                   54.713333   73.856429
# Mico Layout                   39.000000   72.821429
# ITPL                          47.578750   72.465000
# Balagere                      53.794167   69.854545
# Vishwapriya Layout            38.000000   69.272727
# 8th Phase JP Nagar            45.978333   68.421176
# Budigere                      56.725000   68.230769
# 5th Phase JP Nagar            39.000000   65.215385
# Mysore Road                   57.251111   65.201200
# Mahadevpura                   45.000000   63.642105
# Bommanahalli                  32.300000   63.348636
# Begur                         46.700000   62.888889
# Neeladri Nagar                30.000000   61.772727
# Varthur Road                  54.317778   59.290000
# Gunjur                        47.342500   59.228333
# LB Shastri Nagar              48.500000   58.687500
# GM Palaya                     47.975000   58.600000
# Malleshpalya                  46.680000   58.450000
# Hormavu                       53.314375   57.803889
# Kaggadasapura                 39.000000   56.847917
# Anandapura                    46.177500   56.691176
# Uttarahalli                   51.943636   52.968152
# Kothannur                     36.400000   52.917857
# Babusapalaya                  38.950000   51.981429
# Chikkalasandra                45.480000   51.252667
# Electronic City Phase II      39.996182   50.221000
# Kengeri                       28.884286   49.043103
# Dommasandra                   26.860000   48.983333
# Bommasandra Industrial Area   35.577500   47.500000
# Abbigere                      35.000000   45.315833
# Kengeri Satellite Town        30.963750   43.170769
# Hoskote                       23.000000   41.803462
# Sarjapura - Attibele Road     25.605000   41.237000
# Kammasandra                   32.064000   40.227857
# Chandapura                    23.286250   37.788462
# Anekal                        31.666667   34.278947
# Ananth Nagar                  21.711111   32.445714

# %%
len(pt1)
# Out:
# 83

# %% [markdown]
# ### Location where non-move-in ready house are more expensive.

# %%
pt0 = pt[pt[1] < pt[0]].sort_values(0, ascending = False)
pt0
# Out:
# ready_to_move                      0           1
# location
